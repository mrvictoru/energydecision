# %%
# Repository bootstrap for relocated notebooks
from pathlib import Path
import os
import sys

def _find_repo_root(start: Path) -> Path:
    for candidate in (start, *start.parents):
        if (candidate / "README.md").exists() and (candidate / "src").exists():
            return candidate
    return start

REPO_ROOT = _find_repo_root(Path.cwd().resolve())
os.chdir(REPO_ROOT)
for _extra_path in (REPO_ROOT, REPO_ROOT / "src"):
    _extra_str = str(_extra_path)
    if _extra_str not in sys.path:
        sys.path.insert(0, _extra_str)

DATA_DIR = REPO_ROOT / "data"
MODELS_DIR = REPO_ROOT / "models"
EVAL_OUTPUT_DIR = REPO_ROOT / "eval_output"
CONFIGS_DIR = REPO_ROOT / "configs"

# %%
import multiprocessing
multiprocessing.set_start_method("spawn", force=True)

# %%
# read csv file and print out the data
import csv
import sys
import os
import polars as pl
import matplotlib.pyplot as plt
import numpy as np

from helper import transform_polars_df

import torch
# check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
device = 'cpu'

# %%
datapath = 'data/2010-2011 Solar home electricity data.csv'
# skip the first line in csv and read the next line as column
# then read the rest of the file and store as dataframe
df = pl.read_csv(datapath, skip_rows=1)
print(df)
print(df.columns)

# %%
datapath = 'data/2012-2013 Solar home electricity data v2.csv'
# skip the first line in csv and read the next line as column
# then read the rest of the file and store as dataframe
df = pl.read_csv(datapath, skip_rows=1)
print(df)
print(df.columns)
# Out:
# shape: (268_557, 54)
# ┌──────────┬───────────┬──────────┬──────────────────────┬───┬───────┬───────┬───────┬─────────────┐
# │ Customer ┆ Generator ┆ Postcode ┆ Consumption Category ┆ … ┆ 23:00 ┆ 23:30 ┆ 0:00  ┆ Row Quality │
# │ ---      ┆ Capacity  ┆ ---      ┆ ---                  ┆   ┆ ---   ┆ ---   ┆ ---   ┆ ---         │
# │ i64      ┆ ---       ┆ i64      ┆ str                  ┆   ┆ f64   ┆ f64   ┆ f64   ┆ str         │
# │          ┆ f64       ┆          ┆                      ┆   ┆       ┆       ┆       ┆             │
# ╞══════════╪═══════════╪══════════╪══════════════════════╪═══╪═══════╪═══════╪═══════╪═════════════╡
# │ 1        ┆ 3.78      ┆ 2076     ┆ CL                   ┆ … ┆ 0.0   ┆ 0.0   ┆ 1.081 ┆ null        │
# │ 1        ┆ 3.78      ┆ 2076     ┆ GC                   ┆ … ┆ 0.651 ┆ 0.09  ┆ 0.068 ┆ null        │
# │ 1        ┆ 3.78      ┆ 2076     ┆ GG                   ┆ … ┆ 0.0   ┆ 0.0   ┆ 0.0   ┆ null        │
# ...

# %%
# get all the unique customers as their own dataframes
customers = df['Customer'].unique()
# pick 80% of the random customers as training data
training_customers = np.random.choice(customers, int(0.8*len(customers)), replace=False)
# the rest of the customers are testing data
testing_customers = np.setdiff1d(customers, training_customers)

# %%
# save the customers number to a csv file
np.savetxt('data/training_customers.csv', training_customers, fmt='%s')
np.savetxt('data/testing_customers.csv', testing_customers, fmt='%s')

# %%
# alternatively, we can get the training and testing customers from the csv file
training_customers = np.loadtxt('data/training_customers.csv', dtype=int)
testing_customers = np.loadtxt('data/testing_customers.csv', dtype=int)

# %%
# loop through each customer and use transform_polars_df to get the dataframe and store it in a list call dataset
training_dataset = []
for customer in training_customers:
    customer_df = df.filter(pl.col('Customer') == customer)
    try:
        newcustomerdf = transform_polars_df(customer_df, import_energy_price=0.23, export_energy_price=0.015, price_periods="7am – 10am | 4pm – 9pm", default_import_energy_price=0.15, default_export_energy_price=0.01)
    except Exception as e:
        print(f"Error with customer as training dataset: {customer}")
        print(e)
        break
    training_dataset.append(newcustomerdf)

testing_dataset = []
for customer in testing_customers:
    customer_df = df.filter(pl.col('Customer') == customer)
    try:
        newcustomerdf = transform_polars_df(customer_df, import_energy_price=0.23, export_energy_price=0.015, price_periods="7am – 10am | 4pm – 9pm", default_import_energy_price=0.15, default_export_energy_price=0.01)
    except Exception as e:
        print(f"Error with customer as testing dataset: {customer}")
        print(e)
        break
    testing_dataset.append(newcustomerdf)

# %%
# provide std and mean on the different columns of the training dataset
testdf = testing_dataset[25]
# drop timestamp and time columns
testdf = testdf.drop(['Timestamp', 'Time'])
print(testdf.describe())

# %%
import gymnasium as gym

from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.env_checker import check_env
from EnergySimEnv import SolarBatteryEnv
from helper import make_env

# Create a list of environment creation functions to build a vectorized environment.
training_env_fns = [make_env(ds) for ds in training_dataset]
training_vec_env = DummyVecEnv(training_env_fns)

num_total_steps = len(training_dataset[0])
print(f"Total number of steps possible in training dataset: {num_total_steps}")

testing_env_fns = [make_env(ds) for ds in testing_dataset]
# Out:
# Total number of steps possible in training dataset: 17519
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:236: UserWarning: WARN: Box low's precision lowered by casting to float32, current low.dtype=float64
#   gym.logger.warn(
# /usr/local/lib/python3.10/dist-packages/gymnasium/spaces/box.py:306: UserWarning: WARN: Box high's precision lowered by casting to float32, current high.dtype=float64
#   gym.logger.warn(

# %%
num_step = None # pick the number of step for the simulation
test_envs = [env_fn(num_step) for env_fn in testing_env_fns]
#train_envs = [env_fn(num_step) for env_fn in training_env_fns]
#combined_envs = test_envs + train_envs

# %%
from decision import Agent, run_episodes_parallel, run_single
from decision_transformer import DecisionTransformer
import json
import os

with open('models/decision_transformer_model_kwargs.json', 'r') as f:
    model_kwargs = json.load(f)

model = DecisionTransformer(**model_kwargs)

ckpt_path = "models/dt_model_checkpoint.pt"
weights_path = "models/dt_model.pt"
load_path = ckpt_path if os.path.exists(ckpt_path) else weights_path

model.load_from_checkpoint(load_path, map_location=device)
print(f"Loaded DT weights from {load_path}. return_scale={model.return_scale}")

model.eval()

dt_agent_kwargs = {
    'algorithm': 'dt',
    'model': model.to(device),
    'rtg_value': 100.0
}

#testing_log = run_single(Agent, test_envs[0], agent_kwargs=dt_agent_kwargs, render=False, display_progress=True)
# print the first 5 rows of the testing_log
# print(testing_log.head(5))

# %%
import math

bad_params = [name for name, p in model.named_parameters() if torch.isnan(p).any() or torch.isinf(p).any()]
print("bad params:", bad_params)
# Out:
# bad params: []

# %%
episode_log = run_episodes_parallel(Agent, test_envs, agent_kwargs=dt_agent_kwargs, max_workers=2, use_notebook_tqdm=False)
# Out:
# [INFO] Starting 60 episodes with max_workers=2
# Episodes:   0%|          | 0/60 [00:00<?, ?it/s]/code/src/decision.py:194: RuntimeWarning: overflow encountered in cast
#   np.array(self.dt_rtgs_buffer, dtype=np.float32)
# /code/src/decision.py:194: RuntimeWarning: overflow encountered in cast
#   np.array(self.dt_rtgs_buffer, dtype=np.float32)
# Episodes: 100%|██████████| 60/60 [28:21<00:00, 28.37s/it]
# [START] Episode 1
# Sim Complete
# [DONE]  Episode 1 (Elapsed: 65.53 sec)
# [START] Episode 3
# Sim Complete
# [DONE]  Episode 3 (Elapsed: 65.12 sec)
# [START] Episode 5
# Sim Complete
# [DONE]  Episode 5 (Elapsed: 65.22 sec)
# [START] Episode 7
# Sim Complete
# [DONE]  Episode 7 (Elapsed: 65.38 sec)
# [START] Episode 9
# Sim Complete
# [DONE]  Episode 9 (Elapsed: 65.15 sec)
# [START] Episode 11
# Sim Complete
# [DONE]  Episode 11 (Elapsed: 65.67 sec)
# [START] Episode 14
# Sim Complete
# [DONE]  Episode 14 (Elapsed: 64.93 sec)
# [START] Episode 17
# Sim Complete
# ...

# %%
import polars as pl

dfs_with_id = [df.with_columns(pl.lit(i).alias("episode_id")) for i, df in enumerate(episode_log)]
dt_logs = pl.concat(dfs_with_id)
dt_logs.write_parquet("data/dt_rtg10_test_episode_02_logs.parquet")

# %%
from decision import Agent, run_episodes_parallel
rule_agent_kwargs = {
    'algorithm': 'rule'
}

episode_logs = run_episodes_parallel(Agent, train_envs, agent_kwargs=rule_agent_kwargs, max_workers=12, use_notebook_tqdm=False)

# %%
episode_logs

# %%
import polars as pl

dfs_with_id = [df.with_columns(pl.lit(i).alias("episode_id")) for i, df in enumerate(episode_logs)]
rule_all_logs = pl.concat(dfs_with_id)
rule_all_logs.write_parquet("data/rule_train_episode_02_logs.parquet")

# %%
from decision import Agent, run_episodes_parallel, run_single
# Initialize environments and SDP agent parameters
sdp_agent_kwargs = {
    'algorithm': 'sdp',
    'soc_resolution': 20,
    'action_resolution': 41,  # best to be 2*soc_resolution + 1
    'degradation_model': 'linear', # the other option being static degradation 'static'
    'linear_deg_cost_p_kwh': 0.2 # only needed if using linear
}

# Run a single episode for timing test
#sdp_single_log = run_single(Agent, combined_envs[0], agent_kwargs=sdp_agent_kwargs, render=False, display_progress=True)


# Run all episodes in parallel
sdp_episode_logs = run_episodes_parallel(Agent, train_envs, agent_kwargs=sdp_agent_kwargs, max_workers=12, use_notebook_tqdm=False)

# %%
import polars as pl
dfs_with_id = [df.with_columns(pl.lit(i).alias("episode_id")) for i, df in enumerate(sdp_episode_logs)]
sdp_all_logs = pl.concat(dfs_with_id)
sdp_all_logs.write_parquet("data/sdp_train_episode_02_logs.parquet")

# %%
from decision import Agent, run_episodes_parallel, run_single
mrdp_agent_kwargs = {
    'algorithm': 'mrdp',
    'soc_resolution': 20,           # fallback/default for single-horizon
    'action_resolution': 41,        # fallback/default for single-horizon
    'degradation_model': 'linear',  # or 'static'
    'linear_deg_cost_p_kwh': 0.2,   # only needed if using linear
    'subhorizon_specs': [
        {
            'start': 0,
            'length': 12,           # e.g. 6 hours at 30-min steps
            'soc_res': 20,          # fine SoC discretization
            'action_res': 11,       # fine action discretization
            'step_duration': 0.5    # hours per step (30 min)
        },
        {
            'start': 12,
            'length': 36,           # e.g. 18 hours at 30-min steps
            'soc_res': 8,           # coarse SoC discretization
            'action_res': 5,        # coarse action discretization
            'step_duration': 1.0    # hours per step (1 hour)
        }
    ]
}

#sdp_single_log = run_single(Agent, combined_envs[0], agent_kwargs=mrdp_agent_kwargs, render=False, display_progress=True)

# Run all episodes in parallel using MRDP

mrdp_episode_logs = run_episodes_parallel(
    Agent, train_envs, agent_kwargs=mrdp_agent_kwargs, max_workers=12, use_notebook_tqdm=False
)

# %%
import polars as pl
dfs_with_id = [df.with_columns(pl.lit(i).alias("episode_id")) for i, df in enumerate(mrdp_episode_logs)]
mrdp_episode_logs = pl.concat(dfs_with_id)
mrdp_episode_logs.write_parquet("data/mrdp_train_episode_02_logs.parquet")

# %%
from stable_baselines3 import PPO, A2C, DDPG, SAC, TD3
from sb3train import train_model

#ppo_model, _ = train_model(model_class=PPO, vec_env=training_vec_env, total_timesteps= num_total_steps, eval_env_fn=testing_env_fns[5], default_model=True)
# Out:
# Failed to start the Kernel 'Python 3 (ipykernel)'.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details. Unable to get resolved server information for ms-toolsai.jupyter:_builtin.jupyterServerUrlProvider:662e0d2e-8a02-4d44-9b70-e0485c3da5f9

# %%
a2c_model, a2c_training_info = train_model(model_class=A2C, vec_env=training_vec_env, total_timesteps= num_total_steps, eval_env_fn=testing_env_fns[4], default_model=True)

# %%
a2c_model.save("models/a2c_model.zip")

# %%
PPO_model, ppo_training_info = train_model(model_class=PPO, vec_env=training_vec_env, total_timesteps= num_total_steps, eval_env_fn=testing_env_fns[4], default_model=True)

# %%
PPO_model.save("models/ppo_model.zip")

# %%
ddpg_model, ddpg_training_info = train_model(model_class=DDPG, vec_env=training_vec_env, total_timesteps= num_total_steps, eval_env_fn=testing_env_fns[4], default_model=True)

# %%
ddpg_model.save("models/ddpg_model.zip")

# %%
sac_model, sac_training_info = train_model(model_class=SAC, vec_env=training_vec_env, total_timesteps= num_total_steps, eval_env_fn=testing_env_fns[4], default_model=True)

# %%
sac_model.save("models/sac_model.zip")

# %%
td3_model, td3_training_info = train_model(model_class=TD3, vec_env=training_vec_env, total_timesteps= num_total_steps, eval_env_fn=testing_env_fns[4], default_model=True)

# %%
td3_model.save('models/td3_model.zip')

# %%
from decision import Agent, run_sb3_model_on_vec_env

import multiprocessing

# (only needed if you ever switch to SubprocVecEnv on Linux/notebooks)
multiprocessing.set_start_method("forkserver", force=True)

#from stable_baselines3.common.vec_env import SubprocVecEnv
#test_vec_env = SubprocVecEnv(testing_env_fns)
#train_vec_env = SubprocVecEnv(training_env_fns)

from helper import flatten_episode_data

# %%
sac_model = SAC.load("models/sac_model.zip")

# %%
# Run test episodes in parallel
sac_episode_logs = run_sb3_model_on_vec_env(sac_model, training_vec_env)

# %%
sac_logs = flatten_episode_data(sac_episode_logs)
sac_logs.write_parquet("data/sac_train_episode_02_logs.parquet")

# %%
PPO_model = PPO.load("models/ppo_model.zip")

# %%
ppo_episode_logs = run_sb3_model_on_vec_env(PPO_model, training_vec_env)

# %%
ppo_logs = flatten_episode_data(ppo_episode_logs)
ppo_logs.write_parquet("data/ppo_train_episode_02_logs.parquet")

# %%
a2c_model = A2C.load("models/a2c_model.zip")

# %%
a2c_episode_logs = run_sb3_model_on_vec_env(a2c_model, training_vec_env)

# %%
a2c_logs = flatten_episode_data(a2c_episode_logs)
a2c_logs.write_parquet("data/a2c_train_episode_02_logs.parquet")

# %%
ddpg_model = DDPG.load("models/ddpg_model.zip")

# %%
ddpg_episode_logs = run_sb3_model_on_vec_env(ddpg_model, training_vec_env)

# %%
ddpg_logs = flatten_episode_data(ddpg_episode_logs)
ddpg_logs.write_parquet("data/ddpg_train_episode_02_logs.parquet")

# %%
td3_model = TD3.load("models/td3_model.zip")

# %%
td3_episode_logs = run_sb3_model_on_vec_env(td3_model, training_vec_env)

# %%
td3_logs = flatten_episode_data(td3_episode_logs)
td3_logs.write_parquet("data/td3_train_episode_02_logs.parquet")

# %%
# test loading custom dataset class
import polars as pl
import torch
from torch.utils.data import DataLoader

from transformer_training import TrajectoryDataset, concat_trajectory_datasets
from decision_transformer import DecisionTransformer
from EnergySimEnv import SolarBatteryEnv
from helper import transform_polars_df

# %%
# 1) Get env (to grab state_dim, act_dim)

# Load data
datapath = 'data/2011-2012 Solar home electricity data v2.csv'
# skip the first line in csv and read the next line as column
df = pl.read_csv(datapath, skip_rows=1)
# then get the data of customer 1
customer_df = df.filter(pl.col('Customer') == 1)
newcustomerdf = transform_polars_df(customer_df, import_energy_price=0.23, export_energy_price=0.015, price_periods="7am – 10am | 4pm – 9pm", default_import_energy_price=0.15, default_export_energy_price=0.01)
env = SolarBatteryEnv(newcustomerdf)
state_dim = env.observation_space.shape[0]
act_dim   = env.action_space.shape[0]
context_length = 24
# Get the maximum possible timestep from the environment's data length
max_steps_in_episode = len(env.df)

print("State_dim:", state_dim)
print("Act_dim:", act_dim)
print("Max_steps_in_episode:", max_steps_in_episode)

# %%
# 2) Load dataset + DataLoader

ds = TrajectoryDataset(
    data_path       = "data/rule_test_episode_01_logs.parquet",
    context_length  = context_length,
    state_dim       = state_dim,
    act_dim         = act_dim,
    discount_factor = 0.99,
)
loader = DataLoader(ds, batch_size=2, shuffle=False)

# grab a single batch
batch = next(iter(loader))
# shapes should be [B, T, …]
states    = batch["states"]    # (2, T, state_dim)
actions   = batch["actions"]   # (2, T, act_dim)
rtgs      = batch["rtgs"]      # (2, T, 1)
timesteps = batch["timesteps"] # (2, T)
mask      = batch["mask"]      # (2, T)

# %%
states

# %%
print("States shape:", states.shape)
print("Actions shape:", actions.shape)
print("RTGs shape:", rtgs.shape)
print("Timesteps shape:", timesteps.shape)
print("Mask shape:", mask.shape)

# %%
state_dim = 12
act_dim = 1
max_steps_in_episode = 17567
context_length = 36

# %%
context_length = 24

# %%
# 3) Instantiate your DecisionTransformer

model_kwargs = dict(
    state_dim   = state_dim,
    act_dim     = act_dim,
    n_block     = 2,
    h_dim       = 128,
    context_len = context_length,
    n_heads     = 8,
    drop_p      = 0.1,
    max_timestep= max_steps_in_episode,
)

import json
# save model_kwargs to a json file
with open("models/decision_transformer_model_kwargs.json", "w") as f:
    json.dump(model_kwargs, f)

model = DecisionTransformer(**model_kwargs)

# %%
# forward pass
ret_pred, state_pred, act_pred = model(states, rtgs, timesteps, actions)
print("return_preds:", ret_pred.shape)  # expect (2, T, 1)
print("state_preds: ", state_pred.shape) # expect (2, T, state_dim)
print("act_preds:   ", act_pred.shape)   # expect (2, T, act_dim)

# %%
# 4) Example of using the same model for inference in your env
obs, _ = env.reset()
# build zero-padded history for first T steps
hist_states    = torch.zeros(1, context_length, state_dim, dtype=torch.float32)
hist_actions   = torch.zeros(1, context_length, act_dim,   dtype=torch.float32)
hist_rtgs      = torch.zeros(1, context_length, 1,         dtype=torch.float32)
hist_timesteps = torch.zeros(1, context_length, dtype=torch.long)

# fill only the last slot with the current obs
hist_states[0, -1]    = torch.from_numpy(obs)
hist_timesteps[0, -1] = 0

# model returns (ret, state, action)
_, _, action = model(hist_states, hist_rtgs, hist_timesteps, hist_actions)
print("predicted action for env step 0:", action[0, -1].detach().numpy())

# %%
print(training_data_files)

# %%
# get the data path that ends with parquet under the data directory
import os
data_dir = '../data'
#parquet_files = [f for f in os.listdir(data_dir) if f.endswith('.parquet')]
# load them as TrajectoryDataset
datasets = []
for p_file in training_data_files:
    file_path = os.path.join(data_dir, p_file)
    print(f"Loading dataset from: {file_path}")
    dataset = TrajectoryDataset(
        data_path=file_path,
        context_length=context_length,
        state_dim=state_dim,
        act_dim=act_dim,
        discount_factor=0.99
    )
    datasets.append(dataset)
    # You can now use this dataset for training or evaluation
    print(f"Dataset loaded with {len(dataset)} trajectories.")

# Concatenate all datasets into one
if datasets:
    combined_dataset = concat_trajectory_datasets(datasets)
    print(f"Combined dataset has {len(combined_dataset)} trajectories.")

# %%
# split a combined dataset into training and validation sets
train_size = int(0.9 * len(combined_dataset))
val_size = len(combined_dataset) - train_size
train_dataset, val_dataset = torch.utils.data.random_split(combined_dataset, [train_size, val_size])
print(f"Training dataset size: {len(train_dataset)}")
print(f"Validation dataset size: {len(val_dataset)}")

# %%
# test run training loop
from transformer_training import train_decision_transformer, TrajectoryDataset

# Assume previous cells have defined:
# - model: DecisionTransformer instance
# - ds: TrajectoryDataset instance
# - context_length, state_dim, act_dim, max_steps_in_episode

trained_model, train_losses, val_losses = train_decision_transformer(
    ds=train_dataset,
    model=model,
    batch_size=6,
    lr=2e-5,
    epochs=2,
    device="cuda" if torch.cuda.is_available() else "cpu",
    save_path="models/dt_model.pt",
    checkpoint_path="models/dt_model_checkpoint.pt",
    checkpoint_interval=1,
    checkpoints_per_epoch=6,
    val_ds=val_dataset
)

print("Training complete. Final loss:", train_losses[-1])

# %%
# plot training and validation loss curves
import matplotlib.pyplot as plt
plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Decision Transformer Training and Validation Loss')
plt.legend()
plt.show()

# %%
# if the training run crashed a need to resume from last checkpoint
from transformer_training import train_decision_transformer, TrajectoryDataset
trained_model, train_losses, val_losses = train_decision_transformer(
    ds=train_dataset,
    model=model,
    batch_size=4,
    lr=2e-5,
    epochs=2,
    device="cuda" if torch.cuda.is_available() else "cpu",
    save_path="models/dt_model_new.pt",
    resume=True,
    checkpoint_path="models/dt_model_checkpoint.pt",
    val_ds=val_dataset,
)

# %%
# read parquet as polars dataframe
# fetch files name with matching patten
matchs = ["train_episode_01", "train_episode_02", "test_episode_01"]

import os
import polars as pl

def get_matching_files(directory, pattern):
    """
    Returns a list of file paths in 'directory' whose names contain 'pattern'.
    """
    return [
        os.path.join(directory, fname)
        for fname in os.listdir(directory)
        if pattern in fname
    ]

training_data_files = []
for matchs in matchs:
    training_data_files.extend(get_matching_files("../data", matchs))

# %%
import os, re, polars as pl

# use a looser matcher so files like:
#  - dt_rtg03_test_episode_02_logs.parquet
#  - dt_test_episode_02_rtg03_logs.parquet
# are both returned
matching_files = get_matching_files("../data", "test_episode_02")

# capture algorithm at start, trailing _logs (allow optional .parquet)
pat = re.compile(r"^(?P<algo>[A-Za-z0-9]+).*?_logs(?:\.parquet)?$", re.IGNORECASE)
# find _rtgNN anywhere in the name
rtg_search_re = re.compile(r"_rtg(?P<rtg>\d+)", re.IGNORECASE)

test_logs: dict[str, pl.DataFrame] = {}
skipped = []

for file_path in matching_files:
    fname = os.path.basename(file_path)
    m = pat.match(fname)
    if not m:
        print(f"Skipping unrecognized filename: {fname}")
        skipped.append(fname)
        continue

    algo = m.group("algo")
    rtg_m = rtg_search_re.search(fname)
    rtg = rtg_m.group("rtg") if rtg_m else None
    label = f"{algo}_rtg{rtg}" if rtg else algo

    # try to read parquet; if unreadable or empty, register empty DF so label exists
    try:
        if os.path.getsize(file_path) == 0:
            df = pl.DataFrame()
            print(f"Warning: zero-byte file -> empty DF for {label}: {fname}")
        else:
            df = pl.read_parquet(file_path)
    except Exception as e:
        print(f"Failed to read {fname}: {e} -> registering empty DF for {label}")
        df = pl.DataFrame()

    # ensure episode_id exists for non-empty frames
    if not df.is_empty() and "episode_id" not in df.columns:
        df = df.with_columns(pl.lit(0).alias("episode_id"))

    test_logs[label] = df
    print(f"Registered: {fname} -> label='{label}', rows={len(df)}")

print("Final labels:", list(test_logs.keys()))
print("Skipped files:", skipped)

# Access logs, e.g.:
sdp_test_logs = test_logs.get("sdp")
mrdp_test_logs = test_logs.get("mrdp")
ddpg_test_logs = test_logs.get("ddpg")
td3_test_logs = test_logs.get("td3")
sac_test_logs = test_logs.get("sac")
a2c_test_logs = test_logs.get("a2c")
ppo_test_logs = test_logs.get("ppo")
rule_test_logs = test_logs.get("rule")
dt_rtg30_logs   = test_logs.get("dt_rtg30")
dt_rtg10_logs   = test_logs.get("dt_rtg10")
dt_rtg03_logs   = test_logs.get("dt_rtg03")
# Out:
# Registered: sdp_test_episode_02_logs.parquet -> label='sdp', rows=962779
# Registered: ddpg_test_episode_02_logs.parquet -> label='ddpg', rows=945262
# Registered: sac_test_episode_02_logs.parquet -> label='sac', rows=808946
# Registered: dt_rtg03_test_episode_02_logs.parquet -> label='dt_rtg03', rows=945262
# Registered: td3_test_episode_02_logs.parquet -> label='td3', rows=945262
# Registered: mrdp_test_episode_02_logs.parquet -> label='mrdp', rows=963025
# Registered: dt_rtg10_test_episode_02_logs.parquet -> label='dt_rtg10', rows=945262
# Registered: a2c_test_episode_02_logs.parquet -> label='a2c', rows=3684914
# Registered: ppo_test_episode_02_logs.parquet -> label='ppo', rows=674616
# Registered: rule_test_episode_02_logs.parquet -> label='rule', rows=889581
# Registered: dt_rtg30_test_episode_02_logs.parquet -> label='dt_rtg30', rows=962779
# Final labels: ['sdp', 'ddpg', 'sac', 'dt_rtg03', 'td3', 'mrdp', 'dt_rtg10', 'a2c', 'ppo', 'rule', 'dt_rtg30']
# Skipped files: []

# %%
dt_rtg10_logs.count()
# Out:
# shape: (1, 7)
# ┌────────┬──────────────────┬─────────────────┬────────┬────────┬────────┬────────────┐
# │ step   ┆ norm_observation ┆ raw_observation ┆ action ┆ reward ┆ info   ┆ episode_id │
# │ ---    ┆ ---              ┆ ---             ┆ ---    ┆ ---    ┆ ---    ┆ ---        │
# │ u32    ┆ u32              ┆ u32             ┆ u32    ┆ u32    ┆ u32    ┆ u32        │
# ╞════════╪══════════════════╪═════════════════╪════════╪════════╪════════╪════════════╡
# │ 945262 ┆ 945262           ┆ 945262          ┆ 945262 ┆ 945262 ┆ 945262 ┆ 945262     │
# └────────┴──────────────────┴─────────────────┴────────┴────────┴────────┴────────────┘

# %%
# check how many rows in reward is of Nan
dt_rtg10_logs.filter(pl.col("reward").is_nan()).count()
# Out:
# shape: (1, 7)
# ┌──────┬──────────────────┬─────────────────┬────────┬────────┬──────┬────────────┐
# │ step ┆ norm_observation ┆ raw_observation ┆ action ┆ reward ┆ info ┆ episode_id │
# │ ---  ┆ ---              ┆ ---             ┆ ---    ┆ ---    ┆ ---  ┆ ---        │
# │ u32  ┆ u32              ┆ u32             ┆ u32    ┆ u32    ┆ u32  ┆ u32        │
# ╞══════╪══════════════════╪═════════════════╪════════╪════════╪══════╪════════════╡
# │ 0    ┆ 0                ┆ 0               ┆ 0      ┆ 0      ┆ 0    ┆ 0          │
# └──────┴──────────────────┴─────────────────┴────────┴────────┴──────┴────────────┘

# %%
from helper import evaluate_experiment_logs

# Split into a list of DataFrames, one per episode
baseline_logs = [rule_test_logs.filter(pl.col("episode_id") == eid) for eid in rule_test_logs["episode_id"].unique()]

# Evaluate
metrics = evaluate_experiment_logs(baseline_logs)
print(metrics)

# %%
from helper import evaluate_experiments
# Split into a list of DataFrames, one per episode
all_logs = {
    label: [df.filter(pl.col("episode_id") == eid) for eid in df["episode_id"].unique()]
    for label, df in test_logs.items()
}

metrics = evaluate_experiments(all_logs, target_return=0.0)

# %%
# python
import sys


import polars as pl
from helper import transform_polars_df
from test_quantile_scenarios import TestQuantileScenarioGenerator
from quantile_scenarios import QuantileScenarioGenerator

# 1. Load your raw CSV data
raw_df = pl.read_csv('data/2010-2011 Solar home electricity data.csv', skip_rows=1)  # update path as needed

# 2. Transform it using your helper
transformed_df = transform_polars_df(
    raw_df,
    import_energy_price=0.23,
    export_energy_price=0.04,
    price_periods="7am – 10am | 4pm – 9pm",
    default_import_energy_price=0.1,
    default_export_energy_price=0.02
)

# 3. Instantiate the scenario generator
gen = QuantileScenarioGenerator(n_scenarios=3)

# 4. Generate scenarios using the transformed dataframe
scenario_df = gen.generate_scenarios(transformed_df, columns=['SolarGen', 'HouseLoad', 'ImportEnergyPrice', 'ExportEnergyPrice'])
print(scenario_df.head())

# 5. (Optional) Use the tester with the transformed dataframe
tester = TestQuantileScenarioGenerator()
tester.sample_df = transformed_df  # override the sample_df with your transformed data
tester.setup_method

# %%
tester.setup_method()
# Now you can run any test method that uses sample_df
test_methods = [
    ("test_initialization_default", tester.test_initialization_default),
    ("test_initialization_custom_scenarios", tester.test_initialization_custom_scenarios),
    ("test_initialization_custom_quantiles", tester.test_initialization_custom_quantiles),
    ("test_initialization_custom_prefix", tester.test_initialization_custom_prefix),
    ("test_generate_scenarios_basic", tester.test_generate_scenarios_basic),
    ("test_generate_scenarios_auto_detect", tester.test_generate_scenarios_auto_detect),
    ("test_generate_scenarios_grouped", tester.test_generate_scenarios_grouped),
    ("test_generate_scenarios_custom_prefix", tester.test_generate_scenarios_custom_prefix),
    ("test_generate_scenarios_single_value", tester.test_generate_scenarios_single_value),
    ("test_generate_scenarios_small_dataset", tester.test_generate_scenarios_small_dataset),
    ("test_get_scenario_columns", tester.test_get_scenario_columns),
    ("test_summarize_scenarios", tester.test_summarize_scenarios),
    ("test_quantile_ordering", tester.test_quantile_ordering),
    ("test_integration_with_polars_operations", tester.test_integration_with_polars_operations),
    ("test_expected_cost_monte_carlo", tester.test_expected_cost_monte_carlo)  # Example of adding a new test
]

for name, func in test_methods:
    try:
        func()
        print(f"{name} passed")
    except Exception as e:
        print(f"{name} failed: {e}")

"""
test_initialization_default passed
test_initialization_custom_scenarios passed
test_initialization_custom_quantiles passed
test_initialization_custom_prefix passed
test_generate_scenarios_basic passed
test_generate_scenarios_auto_detect failed: 
test_generate_scenarios_grouped failed: group_by column 'Customer' not found in DataFrame
test_generate_scenarios_custom_prefix passed
test_generate_scenarios_single_value failed: 'TestQuantileScenarioGenerator' object has no attribute 'single_value_df'
test_generate_scenarios_small_dataset failed: 'TestQuantileScenarioGenerator' object has no attribute 'small_df'
test_get_scenario_columns passed
test_summarize_scenarios passed
test_quantile_ordering passed
test_integration_with_polars_operations failed: unable to find column "Customer"; valid columns: ["Timestamp", "SolarGen", "HouseLoad", "FutureSolar", "FutureLoad", "ImportEnergyPrice", "ExportEnergyPrice", "Time", "scenario_1_SolarGen", "scenario_2_SolarGen", "scenario_3_SolarGen", "scenario_1_HouseLoad", "scenario_2_HouseLoad", "scenario_3_HouseLoad"]
"""
